# %% [markdown]
# <a href="https://colab.research.google.com/github/KIMUTAI2020/ME/blob/main/Brian_Project_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import pandas as pd
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-936b5228-cf49-4964-b60a-e418b29b8643" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-936b5228-cf49-4964-b60a-e418b29b8643">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded.keys()
# Out:
# dict_keys(['M3_House_Worth.csv'])

# %%
df=pd.read_csv('M3_House_Worth.csv')

# %%
df.head()
# Out:
#    HousePrice  StoreArea  BasementArea   LawnArea HouseNetWorth
# 0      138800       29.9            75  11.223911           Low
# 1      155000       44.0           504   9.689869        Medium
# 2      152000       46.2           493  10.192613        Medium
# 3      160000       46.2           510   6.817316        Medium
# 4      226000       48.7           445  10.916215        Medium

# %%
df.tail()
# Out:
#      HousePrice  StoreArea  BasementArea   LawnArea HouseNetWorth
# 311       99900       59.8             0   7.982364           Low
# 312      290000       84.4           740  10.029866          High
# 313       67000       34.6            41   9.529874           Low
# 314      260000       66.0          1300  10.388070          High
# 315       84500        8.1             0  11.454849           Low

# %% [markdown]
# I have uploaded the data succesfully and above are the first and last five entries of the data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 316 entries, 0 to 315
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   HousePrice     316 non-null    int64
#  1   StoreArea      316 non-null    float64
#  2   BasementArea   316 non-null    int64
#  3   LawnArea       316 non-null    float64
#  4   HouseNetWorth  316 non-null    object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 12.5+ KB

# %% [markdown]
# The data has 316 entries (rows) and 5 columns.

# %%
df.isnull()
# Out:
#      HousePrice  StoreArea  BasementArea  LawnArea  HouseNetWorth
# 0         False      False         False     False          False
# 1         False      False         False     False          False
# 2         False      False         False     False          False
# 3         False      False         False     False          False
# 4         False      False         False     False          False
# ..          ...        ...           ...       ...            ...
# 311       False      False         False     False          False
# 312       False      False         False     False          False
# 313       False      False         False     False          False
# 314       False      False         False     False          False
# 315       False      False         False     False          False
#
# [316 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# HousePrice       0
# StoreArea        0
# BasementArea     0
# LawnArea         0
# HouseNetWorth    0
# dtype: int64

# %% [markdown]
# There is no missing values in all entries.

# %%
df.describe()
# Out:
#           HousePrice   StoreArea  BasementArea    LawnArea
# count     316.000000  316.000000    316.000000  316.000000
# mean   213355.272152   48.312658    573.015823    9.913504
# std    122491.768329   24.722463    564.160849    1.558365
# min     39300.000000    1.800000      0.000000    6.213974
# 25%    115000.000000   27.000000      0.000000    9.211559
# 50%    173950.000000   47.600000    402.500000    9.922729
# 75%    294057.750000   67.300000   1107.000000   10.488359
# max    755000.000000  122.000000   2188.000000   21.539383
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['HousePrice'].plot(kind='hist', bins=20, title='HousePrice')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['StoreArea'].plot(kind='hist', bins=20, title='StoreArea')
# ...

# %% [markdown]
# Table above indicates that , the mean shows the average value of each column.
# Min represents the minimum value for each column, and Max the maximum value for each column
# count represents the number of non null entries in each column.
# 25% represents the value in which 25% of the data falls, 50% represents the value in which 50% of the data falls and 75% represents the value in which 75% of the data falls.

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# Box Plot
plt.figure(figsize=(10, 6))
sns.boxplot(x='HouseNetWorth', y='HousePrice', data=df, palette='pastel')
plt.title('House Price across House Net Worth Categories')
plt.show()
# Out:
# <ipython-input-17-ec39baf2330a>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='HouseNetWorth', y='HousePrice', data=df, palette='pastel')

# %% [markdown]
# This box plots indicates the range of house prices for each house net worth category excluding outliers by observing the whiskers.
# It also indicates presence of outliers in the high net worth category, indicating that there is presence of higher house prices than the rest in that category.

# %%
# Line chart for HousePrice over StoreArea
plt.figure(figsize=(10, 6))
sns.lineplot(x='StoreArea', y='HousePrice', data=df, color='blue')
plt.title('House Price vs Store Area')
plt.xlabel('Store Area')
plt.ylabel('House Price')

# Line chart for HousePrice over BasementArea
sns.lineplot(x='BasementArea', y='HousePrice', data=df, color='red')

# Line chart for HousePrice over LawnArea
sns.lineplot(x='LawnArea', y='HousePrice', data=df, color='green')

# Line chart for HousePrice over HouseNetWorth
sns.lineplot(x='HouseNetWorth', y='HousePrice', data=df, color='orange')

plt.legend(['StoreArea', 'BasementArea', 'LawnArea', 'HouseNetWorth'])
plt.show()

# %% [markdown]
# The above line chart shows that the lower the store area the lower the house price and it attracts low net worth category.
# The larger the store area, basement area and lawn area, the higher the house price and it attracts higher networth category.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set style
sns.set_style("whitegrid")

# pairplot with hue
plt.figure(figsize=(10, 8))
sns.pairplot(df, hue="HouseNetWorth", palette="husl")
plt.title('Pairplot with Different Colors based on House Net Worth')
plt.show()

# %%
df.hist(figsize=(12,10),bins=30)
plt.show()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# HousePrice         int64
# StoreArea        float64
# BasementArea       int64
# LawnArea         float64
# HouseNetWorth     object
# dtype: object

# %%
import numpy as np
from scipy import stats

# %%
# Z-score method to identify outliers
z_scores = stats.zscore(df.select_dtypes(include=['float64', 'int64']))
abs_z_scores = np.abs(z_scores)
filtered_entries = (abs_z_scores < 3).all(axis=1)
df_cleaned = df[filtered_entries]

# %%
# Calculate Z-scores for numerical columns
z_scores = np.abs(stats.zscore(df.select_dtypes(include=['float64', 'int64'])))

# Define a threshold for Z-scores
threshold = 3

# Identify outliers
outliers = (z_scores > threshold).any(axis=1)

# Filter out outliers
df_cleaned = df[~outliers]
